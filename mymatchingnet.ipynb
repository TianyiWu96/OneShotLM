# %%
    import torch
    import torch.nn as nn
    import math
    import numpy as np
    import torch.nn.functional as F
    from torch.autograd import Variable


    class CNN_Classifier(nn.Module):
        def __init__(num_channel=64,img_size=28):
            super(Classifier,self).__init()
            self.c1=nn.Conv2d(1,num_channel)
            self.c2=nn.Conv2d(num_channel,num_channel)
            self.c3=nn.Conv2d(num_channel,num_channel)
            self.c4=nn.Conv2d(num_channel,num_channel)
            self.r=F.relu()
            self.bn=nn.BatchNorm2d(num_channel)
            self.mp=nn.MaxPool2d(2,2)
            self.size=math.floor(math.floor(math.floor(math.floor(img_size/2)/2)/2)/2)
            self.size=self.size*self.size*num_channel
            print(self.size)

        def foward(self,img_input):
            x=img_input
            x=self.r(self.bn(self.c1(x)))
            x=self.r(self.bn(self.c2(x)))
            x=self.r(self.bn(self.c3(x)))
            x=self.r(self.bn(self.c4(x)))
            x=x.view(self.size,-1)
            return x

    class LSTM(nn.Module):
        def __init__(in_size=1024,num_img=5,mem_size=1024):
            super(LSTM,self).__init()
            self.wf=Variable(torch.ones(in_size,mem_size),torch,requires_grad=True)
            self.uf=Variable(torch.ones(mem_size,mem_size),torch,requires_grad=True)
            self.bf=Variable(torch.ones(mem_size),torch,requires_grad=True)
            nn.init.xavier_uniform(self.wf.data)
            nn.init.xavier_uniform(self.uf.data)
            nn.init.xavier_uniform(self.bf.data)

            self.wi=Variable(torch.ones(in_size,mem_size),torch,requires_grad=True)
            self.ui=Variable(torch.ones(mem_size,mem_size),torch,requires_grad=True)
            self.bi=Variable(torch.ones(mem_size),torch,requires_grad=True)
            nn.init.xavier_uniform(self.wi.data)
            nn.init.xavier_uniform(self.ui.data)
            nn.init.xavier_uniform(self.bi.data)

            self.wo=Variable(torch.ones(in_size,mem_size),torch,requires_grad=True)
            self.uo=Variable(torch.ones(mem_size,mem_size),torch,requires_grad=True)
            self.bo=Variable(torch.ones(mem_size),torch,requires_grad=True)
            nn.init.xavier_uniform(self.wo.data)
            nn.init.xavier_uniform(self.uo.data)
            nn.init.xavier_uniform(self.bo.data)

            self.wc=Variable(torch.ones(in_size,mem_size),torch,requires_grad=True)
            self.uc=Variable(torch.ones(mem_size,mem_size),torch,requires_grad=True)
            self.bc=Variable(torch.ones(mem_size),torch,requires_grad=True)
            nn.init.xavier_uniform(self.wc.data)
            nn.init.xavier_uniform(self.uc.data)
            nn.init.xavier_uniform(self.bc.data)

            self.wh=Variable(torch.ones(in_size,mem_size),torch,requires_grad=True)
            self.uh=Variable(torch.ones(mem_size,mem_size),torch,requires_grad=True)
            self.bh=Variable(torch.ones(mem_size),torch,requires_grad=True)
            nn.init.xavier_uniform(self.wh.data)
            nn.init.xavier_uniform(self.uh.data)
            nn.init.xavier_uniform(self.bh.data)

        def foward(self,input):
            h=[]
            for i in range(num_img):
                ft=F.sigmoid(self.wf.mm(input[i])+self.uf.mm(_c)+self.bf)
                it=F.sigmoid(self.wi.mm(input[i])+self.ui.mm(_c)+self.bi)
                ot=F.sigmoid(self.wo.mm(input[i])+self.uo.mm(_c)+self.bo)
                ct=ft*_c+it*F.tanh(self.wc.mm(input[i])+self.uc.mm(_c)+self.bc)
                ht=ot*ct
                h.append(ht)
            return torch.stack(h)

    class matching_net(nn.Module):
        def __init__():
            super(matching_net,self).__init()
            self.cnn=CNN_Classifier()
            self.lstm=LSTM()

        def foward(self, support_set, support_set, target_image, target_y):
            for i in support_set:
                x.append(self.cnn(i))
            y=self.cnn(input)
            for i in support_set:
                z.append(i.dot(y)*torch.rsqrt(i.dot(i)*y.dot(y)))
            output=softmax(torch.stack(z))

            values, indices = output.max(1)
            accuracy = torch.mean((indices.squeeze() == target_y).float())
            crossentropy_loss = F.cross_entropy(values, target_y.long())
            return accuracy, crossentropy_loss
